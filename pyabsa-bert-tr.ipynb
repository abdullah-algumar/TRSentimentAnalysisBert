# %%
import pandas as pd
import stanza
import spacy
from transformers import BertTokenizer, BertForSequenceClassification
import torch
# Out:
# 2023-09-28 11:53:01.372549: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Stanza kullanarak Türkçe dil modeli yüklüyoruz 
stanza.download("tr")
nlp_stanza = stanza.Pipeline("tr")
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.1.json: 365kB [00:00, 10.6MB/s]
# 2023-09-28 11:53:09 INFO: Downloading default packages for language: tr (Turkish) ...
# 2023-09-28 11:53:10 INFO: File exists: /home/abdullah/stanza_resources/tr/default.zip
# 2023-09-28 11:53:14 INFO: Finished downloading models and saved to /home/abdullah/stanza_resources.
# 2023-09-28 11:53:14 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.1.json: 365kB [00:00, 10.8MB/s]
# 2023-09-28 11:53:14 INFO: Loading these models for language: tr (Turkish):
# =============================
# | Processor | Package       |
# -----------------------------
# | tokenize  | imst          |
# | mwt       | imst          |
# | pos       | imst_charlm   |
# | lemma     | imst_nocharlm |
# | depparse  | imst_charlm   |
# | ner       | starlang      |
# =============================
#
# 2023-09-28 11:53:14 INFO: Using device: cpu
# 2023-09-28 11:53:14 INFO: Loading: tokenize
# 2023-09-28 11:53:14 INFO: Loading: mwt
# 2023-09-28 11:53:14 INFO: Loading: pos
# 2023-09-28 11:53:15 INFO: Loading: lemma
# 2023-09-28 11:53:15 INFO: Loading: depparse
# 2023-09-28 11:53:15 INFO: Loading: ner
# 2023-09-28 11:53:16 INFO: Done loading processors!

# %%
# Verileri bir liste olarak okutalım
texts = []
aspects = []
sentiments = []

train_file_path = "restaurants_train_turkish.txt"

# Dosyaları okuyup verileri ayrıştırmak
def read_train_data(file_path):
    with open(file_path, "r") as train_file:
        train_lines = train_file.readlines()
    for i in range(0, len(train_lines), 3):
        texts.append(train_lines[i].strip())
        aspects.append(train_lines[i + 1].strip())
        sentiments.append(train_lines[i + 2].strip())


read_train_data(train_file_path)

print("Train Texts:", texts)
print("Train Aspects:", aspects)
print("Train Sentiments:", sentiments)
print('-'*100)
# Out:
# Train Texts: ['$T$ sahane evet ama servis rezalet.', 'Manzara sahane evet ama $T$ rezalet.', 'Soguk su isteyince, soguk yok, butun sulari disari cikardik diyen garson, siparisten tam 2 saat sonra gelen yemekler, yemegin yaninda soylenen roka ve pureden eser olmamasi, istedigimiz 2 $T$ de kalmamis olmasi.', 'Soguk su isteyince, soguk yok, butun sulari disari cikardik diyen $T$, siparisten tam 2 saat sonra gelen yemekler, yemegin yaninda soylenen roka ve pureden eser olmamasi, istedigimiz 2 mezenin de kalmamis olmasi.', '$T$ iyi hos, lezzetler iyi ama heyecan verici bi taraflari yok, iyi bir baligi iyi bir sekilde izgara yapmak artik atla deve bi olay degil.', 'Yemekler iyi hos, $T$ iyi ama heyecan verici bi taraflari yok, iyi bir baligi iyi bir sekilde izgara yapmak artik atla deve bi olay degil.', 'bu servise bu $T$ ise cok faZla.', 'Lacivert beni $T$ dusukluguyle cok sasirtti', 'Buraya bu kadar iyi yorum yapanlar her halde daha önce hiç $T$ yemediler.', 'Kalamardan ve koladan önce $T$ ve apar topar önümüze atildi.', 'ayrica gelen $T$ soguk ve sünger gibiydi.', 'Daha önce de söyledigim gibi büyüdükçe $T$ düsen yerlerden', 'Kesinlikle $T$ degil - Bu kadar basarisiz ev yemekleri olmasina ragmen ögle saatlerinde ki yogunlugu çözebilmis degilim.', 'Ya insanlar gerçekten $T$ nasil oldugunu bilmiyorlar.', '1 kere denedigim $T$ yüksek yemeklerinin lezzetsiz oldugu bir mekan önermiyorum.', '1 kere denedigim fiyatlarinin yüksek $T$ lezzetsiz oldugu bir mekan önermiyorum.', 'mekanın girişinde $T$ ışıltılı,sıcak bir ortam yaratılmaya çalışılmış manzara olmadığı için bulunduğu konumda pek samimi bulmadım.', '$T$ ilgisizdi biz söyledikce yaptı buda benim restauranttan beklentimi zayıflatıyor.', '$T$ daha iyisini yedim küşleme güzeldi.', 'lokumun daha iyisini yedim $T$ güzeldi.', 'bilemedim $T$ daha sonra belki bir şans daha verebilirim.', '2 sene önce hızlı bir kahvaltı yapmak için geldiğimiz mekana dair hatırımda kalan 6 tl lik $T$ oldu:', ') menüde dikkat etmemiştik ama hesap gelince ufak bir şok yaşamıştık😩 güzel olabilir ama kahvaltıdan fazla ödediğimiz $T$ yüzünden bir daha uğramadık.', '$T$ öneririm.', '$T$ tereyagli ve yumusak .', 'Sert $T$ sevmeyenler icin cok lezzetliydi.', '$T$ iyi bir uclu oldu.', '$T$ hizli valesi var.', 'Acik mekanda ise $T$ guzel.', 'Bugun çalışan arkadasin yonlendirmesiyle siyah caylardan $T$ ictik.', 'Vanilya tadi gerçekten baya hissediliyodu ama ben $T$ daha cok begenmistim.', '$T$ güzel,özellikle rahat oturma köşeleri👌 Esas kahve sever biri oldugum icin cok tercih ettigim mekan değil ama yine de arada degisiklik icin guzel olabilir.', 'Ortam güzel,özellikle rahat $T$👌 Esas kahve sever biri oldugum icin cok tercih ettigim mekan değil ama yine de arada degisiklik icin guzel olabilir.', 'Yoğun olduğu günlerde(cumartes-pazar) $T$ tavsiye etmem.', 'Şubelerden en iyisi $T$ iyidir.', 'Bugüne kadar dışarıda yediğim en lezzetli $T$.', '$T$ ağızda dağılıyor adeta, lokum gibi.', 'Duyduğum kadarıyla suda değil sütte $T$.', 'Yanında $T$ harika oluyor.', '$T$ da çok lezzetli, mis gibi tereyağ kokuyor.', 'Pilavı da çok lezzetli, mis gibi tereyağ $T$.', 'Finali $T$ yapmanızı tavsiye ediyorum.', '$T$ da enfes.', "Hard Rock Cafe'de hiç sıra beklemeden oturmaya alışık değiliz ki biz, Avrupa veya Amerika'dakilerle aynı duyguyu vermiyor bu sebeple ama $T$ tabii yine aynı.", "Hard Rock Cafe'de hiç $T$ beklemeden oturmaya alışık değiliz ki biz, Avrupa veya Amerika'dakilerle aynı duyguyu vermiyor bu sebeple ama lezzet tabii yine aynı.", '$T$ pek yummy!', '$T$ çok başarılı.', '$T$ zaten mükemmel.', "Bütün istanbul'un güzelliğini, yoğunluğunu $T$.", 'Onun dışında pek $T$ değil.', 'Özel günlerde gidilecek, küçük kutlamalar yapılacak bir $T$', 'Rahatça $T$ istiyorsanız, orta mükemmel.', '$T$ tam kıvamında, rahatsız etmiyor.', '$T$ çok lezzetli, manzara mükemmel.', 'Yemekleri çok lezzetli, $T$ mükemmel.', 'ancak $T$ biraz abartılı geliyor, balık yemeden kişi başı 100 liradan fazla ödedik, itiraz etmek gerekir.', 'Kalabalik zamanlarda ...
# Train Aspects: ['Manzara', 'servis', 'mezenin', 'garson', 'Yemekler', 'lezzetler', 'fiyatlar', 'kalitesinin', 'balik', 'balik geldi', 'kalamar', 'kalitesi', 'ev yemegi', 'ev yemeginin', 'fiyatlarinin', 'yemeklerinin', 'kasap reyonu', 'garsonumuz', 'lokumun', 'küşleme', 'mekana', 'çayı', 'çay', 'Şatobiryanı', 'Sosu', 'et', 'Guvecte yogurt ve salatayla', 'Servisi', 'gardenya bolumu', 'bourbon vanilla', 'beyaz caylarini', 'Ortam', 'oturma köşeleri', 'gitmenizi', 'Pendik merkez ana şubesi', 'kurufasülyeci', 'Fasulyesi', 'bekletiyorlarmış', 'turşu, cacık veya yoğurtla', 'Pilavı', 'kokuyor', 'sütlaçla', 'Sütlacı', 'lezzet', 'sıra', 'Atıştırmalık Jumbo Combo', 'Deniz ürünleri', 'Manzarası', 'hissediyorsun', 'öğrenci mekanı', 'yer', 'sohbet edebilmek', 'Çalan müzik', 'Yemekleri', 'manzara', 'hesap', 'servis', 'siparis', 'masalarin', 'çilekli magnoliasından', 'ortamında', 'yemekler', 'tat', 'Garsonlar', 'Kasarli köftenin', 'yer', 'Isletme sahibi', 'kasarli köfte', 'Müsteri memnuniyeti', 'pide', 'menüde', 'ulaşımı', 'fiyatları', 'pide', 'pideyi', 'tadı', 'Malzemesi', 'porsiyonu', "Beşiktaş'ın göbeğinde", 'deneyim', 'Pide lezzeti', 'siparişleri', 'kenarlarını', 'ortası', 'gelecek', 'Yemek', 'bütçeyi', 'servis', 'kahvalti', 'fiyat', 'manzarası', 'ikram', 'yemekleri', 'istakoz kavurma', 'ızgara mantar', 'yerlerden', 'mezelerde', 'kuskonmaz somon sarma', 'kagitta balik pastirma', 'caylar', 'lezzet', 'Ortam', 'manzara', 'cay', 'mekan', 'köprünün ve hisarın ışıkları', 'canlı müzikle', 'doneri', 'Eti', 'Eti', 'Ortami', 'Eti', 'mekan', 'sunum', 'tabağa', 'Havuç dilimi', 'servis', 'Big Chefs', 'tavuk WRAPimiz', 'kofte durum', 'Tavuklar', 'kofte durum', 'tatla', 'Zeytinyagli tabagi', 'Tadlari', 'koymak', 'Fiyatlar', 'servis', 'tuvaletler', 'bayan', 'manzaraydi', 'servis elemanlari', 'çesit', 'sunum', 'mekan', 'yerlerden', 'garsonlarin', 'servisin', 'garson', 'dondurma spesiyalleri ve tatlililari', 'yerdi', 'Garsonlar', 'göründügü', 'Su böregi', 'Çay', 'manzarasi', 'manzaraya', 'fiyat', 'Gözleme', 'Kuaförü', 'mutfak', 'manzara', 'deniz ürünlerini', 'fiyatlarla', 'Döner', 'restoranda', 'ortam', 'Yeri', 'dösenmis', 'yemekleri', 'yemekleri', 'Sira', 'mekan', 'Manzara', 'ortam', 'karisik köfte tabagi', 'fajita', 'yiyin', 'meze', 'soslarla', 'Balığın', 'balık', 'hızlı', 'Mısır ekmeği', 'hesap', 'çeşit', 'müzikler', 'ortam', 'Mizuno Pudding', "Mizuno Pudding'i", 'paraya', 'Servisten', 'mekan', 'kalabalıktan', 'ev hanımları', 'Garsonlar', 'garsonlarinin', 'getirmeleride', 'Eleos', 'fiyatlar', 'fix menü', 'Mezeler', 'Balkon/teras bölümü', 'servisi', 'mekan', 'Mekanin isletmecisi beyin', 'tavri tarzi konusmasi uslubu', 'Mekanin', 'manzara', 'yemekleride', 'isletmeciyle', 'Yemekler', 'ogle yemeginde', 'bugday salatasi', 'havuc salatasi', 'baklavanın', 'karışık tabak', 'Çikolatalı baklavayıda', 'muzikler', 'manzarasiyla', 'meze ve yemekleriyle', 'Burayi', 'Hersey', 'vakit geçirirsiniz', 'votka', 'şarap', 'müzik', 'mezeleriyle', 'mezeleri', 'çalışanların ilgiside', 'tabak', 'Hamburgerleri', 'kahvaltı', 'Porsiyonları', 'fiyatlar', 'Garsonlar', 'çayları', 'tatlı', 'manzarası', 'çayları', 'Bourbon vanilla', 'Irish Malt', 'Servis', 'çalışanları', 'çayların', 'müzik seçimleri', 'serviste', 'Mekan', 'Servis', 'çeşit', 'çeşitler', 'Fiyatları', 'Yemekler', 'Manzara', 'yemekler', 'servis', 'demlik çay', 'Mekani', 'çesitler', 'servisi', 'Tesis', 'Etler', 'Lezzet', 'Mekan', 'et', 'et', 'Kuru fasulye', 'menü', 'personelinden', 'burasi', 'Kahvaltiliklar', 'menemen', 'kokusu tadi', 'yedigimi', 'mekandır', 'fiyatlar', 'bahçesi', 'mekanda', 'servis', 'lezzetleri', 'ilgi', 'Küçük Ev', 'döner', 'dönerini ve kavurmali pidesini', 'yediklerimizide', 'manda yogurtlarinida', 'kazandibini', 'kaymakli ayva tatlisini', 'Fiyatlar', 'hizmet', 'konumundan', 'ortamini', 'ortami', 'agaç', 'çaba', 'ürünleri', 'kasarli ve kavurmali pide', 'Biberler', 'domates', 'menemen', 'Açik ayrani', 'Manzara', 'cesit', 'yemegi', 'hamburgeri', 'patates kizartmasi', 'sunum', 'yer', 'doyduk', 'çay', 'ücret' ...
# Train Sentiments: ['Positive', 'Negative', 'Negative', 'Negative', 'Positive', 'Positive', 'Negative', 'Negative', 'Negative', 'Negative', 'Negative', 'Negative', 'Negative', 'Negative', 'Negative', 'Negative', 'Negative', 'Negative', 'Neutral', 'Positive', 'Neutral', 'Negative', 'Negative', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Neutral', 'Positive', 'Positive', 'Positive', 'Negative', 'Positive', 'Positive', 'Positive', 'Neutral', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Neutral', 'Positive', 'Positive', 'Positive', 'Positive', 'Neutral', 'Neutral', 'Positive', 'Positive', 'Positive', 'Positive', 'Negative', 'Negative', 'Negative', 'Negative', 'Positive', 'Positive', 'Positive', 'Positive', 'Negative', 'Negative', 'Negative', 'Negative', 'Negative', 'Negative', 'Positive', 'Negative', 'Positive', 'Positive', 'Positive', 'Negative', 'Positive', 'Positive', 'Positive', 'Positive', 'Negative', 'Positive', 'Negative', 'Negative', 'Positive', 'Negative', 'Negative', 'Positive', 'Negative', 'Positive', 'Negative', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Negative', 'Positive', 'Positive', 'Positive', 'Positive', 'Negative', 'Negative', 'Negative', 'Negative', 'Positive', 'Positive', 'Negative', 'Negative', 'Negative', 'Negative', 'Negative', 'Negative', 'Negative', 'Negative', 'Neutral', 'Negative', 'Neutral', 'Positive', 'Negative', 'Neutral', 'Negative', 'Negative', 'Negative', 'Positive', 'Negative', 'Positive', 'Negative', 'Positive', 'Positive', 'Negative', 'Negative', 'Negative', 'Neutral', 'Negative', 'Negative', 'Negative', 'Positive', 'Neutral', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Negative', 'Positive', 'Negative', 'Negative', 'Positive', 'Negative', 'Positive', 'Negative', 'Positive', 'Positive', 'Positive', 'Negative', 'Neutral', 'Positive', 'Positive', 'Negative', 'Negative', 'Negative', 'Positive', 'Positive', 'Neutral', 'Negative', 'Positive', 'Positive', 'Negative', 'Positive', 'Positive', 'Positive', 'Negative', 'Negative', 'Negative', 'Positive', 'Positive', 'Negative', 'Negative', 'Positive', 'Negative', 'Negative', 'Negative', 'Negative', 'Negative', 'Neutral', 'Negative', 'Negative', 'Negative', 'Negative', 'Negative', 'Negative', 'Neutral', 'Negative', 'Negative', 'Positive', 'Negative', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Negative', 'Negative', 'Negative', 'Positive', 'Positive', 'Positive', 'Negative', 'Neutral', 'Negative', 'Negative', 'Negative', 'Negative', 'Negative', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Negative', 'Positive', 'Positive', 'Positive', 'Negative', 'Positive', 'Positive', 'Positive', 'Positive', 'Negative', 'Negative', 'Positive', 'Positive', 'Positive', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Negative', 'Negative', 'Positive', 'Positive', 'Negative', 'Negative', 'Negative', 'Negative', 'Negative', 'Negative', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Negative', 'Negative', 'Negative', 'Neutral', 'Positive', 'Negative', 'Negative', 'Negative', 'Positive', 'Negative', 'Positive', 'Positive', 'Positive', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Positive', 'Negative', 'Negative', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Neutral', 'Negative', 'Positive', 'Positive', 'Negative', 'Positive', 'Positive', 'Positive', 'Neutral', 'Positive', 'Negative', 'Negative', 'Negative', 'Negative', 'Positive', 'Positive', 'Negative', 'Negative', 'Negative', 'Positive', 'Positive',  ...
# ----------------------------------------------------------------------------------------------------

# %%
# Veri çerçevesini oluşturalım
df = pd.DataFrame({'Tweet': texts, 'Aspect': aspects, 'Sentiment': sentiments})

# %%
df
# Out:
#                                                   Tweet  \
# 0                   $T$ sahane evet ama servis rezalet.
# 1                  Manzara sahane evet ama $T$ rezalet.
# 2     Soguk su isteyince, soguk yok, butun sulari di...
# 3     Soguk su isteyince, soguk yok, butun sulari di...
# 4     $T$ iyi hos, lezzetler iyi ama heyecan verici ...
# ...                                                 ...
# 1380        Tereyağlı pilavları ve $T$ da çok başarılı.
# 1381  Üzerine bal ve fındık dökülmüş $T$ çok cezbedi...
# 1382  Üzerine bal ve fındık dökülmüş sütlaçları çok ...
# 1383  Ayrıca hergun çıkardıkları farklı $T$ de çok b...
# 1384             $T$ ortalamanın biraz ustunde malesef.
#
#                      Aspect Sentiment
# 0                   Manzara  Positive
# 1                    servis  Negative
# 2                   mezenin  Negative
# 3                    garson  Negative
# 4                  Yemekler  Positive
# ...                     ...       ...
# 1380           tava yoğurdu  Positive
# 1381             sütlaçları  Positive
# 1382          sütlaç tadını  Negative
# 1383  zeytinyağlı yemekleri  Positive
# 1384               Fiyatlar  Negative
#
# [1385 rows x 3 columns]

# %%
# Aspect tanıma işlemi için stanza kullaniyoruz
def extract_aspects(text):
    doc = nlp_stanza(text)
    aspects = [ent.text for sent in doc.sentences for ent in sent.ents]
    return aspects

# %%
df['Aspects'] = df['Tweet'].apply(extract_aspects)

# %%
# Duygu analizi için bir önceden eğitilmiş türkçe modeli
tokenizer = BertTokenizer.from_pretrained("dbmdz/bert-base-turkish-uncased")
model = BertForSequenceClassification.from_pretrained("dbmdz/bert-base-turkish-uncased", num_labels=3)  # 3 sınıf için (Positive, Negative, Neutral)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def tokenize_text(text):
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True)
    return inputs

# %%
df['Tokenized'] = df['Tweet'].apply(tokenize_text)

# %%
def sentiment_analysis(tokenized_text):
    input_ids = tokenized_text['input_ids']
    attention_mask = tokenized_text['attention_mask']

    with torch.no_grad():
        outputs = model(input_ids, attention_mask=attention_mask)

    logits = outputs.logits
    predicted_labels = torch.argmax(logits, dim=1)

    return predicted_labels.item()

# %%
df['Predicted_Sentiment'] = df['Tokenized'].apply(sentiment_analysis)

# %%
# Aspect bazlı duygu tahminleri
aspect_sentiments = {}
for index, row in df.iterrows():
    tweet = row['Tweet']
    aspects = row['Aspects']
    sentiment = row['Predicted_Sentiment']
    
    for aspect in aspects:
        if aspect not in aspect_sentiments:
            aspect_sentiments[aspect] = {'Positive': 0, 'Negative': 0, 'Neutral': 0}
        
        if sentiment == 0:
            aspect_sentiments[aspect]['Negative'] += 1
        elif sentiment == 1:
            aspect_sentiments[aspect]['Neutral'] += 1
        elif sentiment == 2:
            aspect_sentiments[aspect]['Positive'] += 1

# %%
aspect_sentiments
# Out:
# {'$T$': {'Positive': 171, 'Negative': 143, 'Neutral': 611},
#  '2 $T$': {'Positive': 0, 'Negative': 1, 'Neutral': 0},
#  'Kalamardan': {'Positive': 0, 'Negative': 1, 'Neutral': 0},
#  '6 tl': {'Positive': 0, 'Negative': 1, 'Neutral': 0},
#  '$T$👌': {'Positive': 1, 'Negative': 0, 'Neutral': 0},
#  "Hard Rock Cafe'de": {'Positive': 1, 'Negative': 0, 'Neutral': 1},
#  'Avrupa': {'Positive': 1, 'Negative': 0, 'Neutral': 1},
#  "Amerika'dakilerle": {'Positive': 1, 'Negative': 0, 'Neutral': 1},
#  'Bosken': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  "Beşiktaş'ta": {'Positive': 1, 'Negative': 0, 'Neutral': 1},
#  'Vanilla': {'Positive': 0, 'Negative': 1, 'Neutral': 0},
#  'Pazar günü': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  'Big Chefs': {'Positive': 1, 'Negative': 0, 'Neutral': 1},
#  'Wrapten': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  "Tuzla'da": {'Positive': 0, 'Negative': 1, 'Neutral': 1},
#  'Marmara': {'Positive': 1, 'Negative': 0, 'Neutral': 0},
#  "İstanbul'da": {'Positive': 1, 'Negative': 1, 'Neutral': 2},
#  'Mizuno Pudding': {'Positive': 0, 'Negative': 4, 'Neutral': 0},
#  '60 $T$': {'Positive': 0, 'Negative': 1, 'Neutral': 0},
#  "Mizuno Pudding'i": {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  'Istanbulda': {'Positive': 0, 'Negative': 1, 'Neutral': 1},
#  '8 lira': {'Positive': 0, 'Negative': 1, 'Neutral': 1},
#  'Combo': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  'Irish Malt': {'Positive': 1, 'Negative': 0, 'Neutral': 0},
#  'Bourbon vanilla': {'Positive': 1, 'Negative': 0, 'Neutral': 0},
#  'Mart ayinin': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  'Trabzon': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  'Rizeden': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  '35tl $T$': {'Positive': 0, 'Negative': 1, 'Neutral': 0},
#  '42 tl $T$': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  '17.90 tl $T$': {'Positive': 0, 'Negative': 1, 'Neutral': 0},
#  '17.90 tl': {'Positive': 0, 'Negative': 1, 'Neutral': 0},
#  '10 tl $T$': {'Positive': 0, 'Negative': 1, 'Neutral': 0},
#  "Istanbul'un": {'Positive': 1, 'Negative': 0, 'Neutral': 0},
#  'Karaköyün': {'Positive': 0, 'Negative': 0, 'Neutral': 2},
#  "Starbucks'ı": {'Positive': 0, 'Negative': 1, 'Neutral': 0},
#  'Num Num': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  'Rumeli Hisari': {'Positive': 1, 'Negative': 0, 'Neutral': 1},
#  "Big Chefs'te": {'Positive': 1, 'Negative': 0, 'Neutral': 0},
#  '5 lira': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  '80 TL.': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  'Machiat': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  "Mado'ların": {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  'Cuma': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  "Magnolia'sı": {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  'Besiktaki': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  '$T$sinde': {'Positive': 1, 'Negative': 0, 'Neutral': 0},
#  'Pazar': {'Positive': 0, 'Negative': 1, 'Neutral': 0},
#  'Big chefs': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  '20 tl': {'Positive': 0, 'Negative': 2, 'Neutral': 1},
#  'bir $T$ 20 tl': {'Positive': 0, 'Negative': 1, 'Neutral': 0},
#  "Sütiş'in": {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  'Emirgan': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  "Taksim'de": {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  'NY': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  '30 dk $T$': {'Positive': 1, 'Negative': 0, 'Neutral': 0},
#  '60 liraya': {'Positive': 1, 'Negative': 0, 'Neutral': 0},
#  '40 tl $T$': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  "Pizzeria Trio'": {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  'Pizza': {'Positive': 1, 'Negative': 0, 'Neutral': 0},
#  'Karakoyde': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  "Göksu'da": {'Positive': 0, 'Negative': 1, 'Neutral': 0},
#  'Kulbasti': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  'Jumbo': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  'press': {'Positive': 1, 'Negative': 0, 'Neutral': 0},
#  'Big Burger': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  'Canyon Road': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  "Otagtepe'nin": {'Positive': 1, 'Negative': 0, 'Neutral': 2},
#  'Fethipaşa': {'Positive': 0, 'Negative': 0, 'Neutral': 3},
#  'Plaza': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  'Boğaziçi Üniversitesi': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  "Kadıköy'de": {'Positive': 1, 'Negative': 1, 'Neutral': 1},
#  "Happy Moon's": {'Positive': 0, 'Negative': 1, 'Neutral': 0},
#  'Hasan Kolcuoğlu': {'Positive': 2, 'Negative': 0, 'Neutral': 0},
#  "Anadolu Yakasi'nda": {'Positive': 0, 'Negative': 2, 'Neutral': 0},
#  '$T$in': {'Positive': 1, 'Negative': 0, 'Neutral': 0},
#  "İstanbul'daki": {'Positive': 2, 'Negative': 0, 'Neutral': 1},
#  '$T$da': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  'Cookshop': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  'Gmall': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  'Tuzla': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  "Dilruba'ya": {'Positive': 0, 'Negative': 1, 'Neutral': 0},
#  'Mabeyn': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  'Besiktas': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  'cumartesi': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  "Tünel'de": {'Positive': 1, 'Negative': 0, 'Neutral': 1},
#  "Anadolu Hisari'nin": {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  'Sabanci Ögretmenevi': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  '100 liraya': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  "Kısıklı'ya": {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  "Hisarustu'ndeki": {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  '$T$indan': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  "Kadıköy'dekl": {'Positive': 0, 'Negative': 2, 'Neutral': 3},
#  'Ramazan ayında': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  "Passion fruit'lu": {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  "Uzunlar'a": {'Positive': 0, 'Negative': 1, 'Neutral': 0},
#  "Istanbul'u": {'Positive': 0, 'Negative': 2, 'Neutral': 0},
#  'Istanbul Bogazinin': {'Positive': 0, 'Negative': 1, 'Neutral': 0},
#  '$T$ine': {'Positive': 1, 'Negative': 0, 'Neutral': 0},
#  'Tavuk Schnitzel': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  "Kadiköy'de": {'Positive': 0, 'Negative': 1, 'Neutral': 0},
#  'English pub': {'Positive': 0, 'Negative': 0, 'Neutral': 3},
#  'İstanbul şubesi': {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  "$T$ hard rock'tan": {'Positive': 0, 'Negative': 0, 'Neutral': 1},
#  "Kuru'da": {'Positive': 0, 'Negative': 2, 'Neutral': 0}}
